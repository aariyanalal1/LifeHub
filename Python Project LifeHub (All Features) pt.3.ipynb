# %%
import tkinter as tk
from tkinter import *
from tkinter.ttk import *

root = tk.Tk()
root.title("LifeHub")
root.configure(background="sky blue")
root.minsize(200, 200)
root.maxsize(500, 500)
root.geometry("600x300+50+50")
text_var = tk.StringVar()
text_var.set("L  i  f  e  H  u  b")
label = tk.Label(root, 
                 textvariable=text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 60, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=15,               
                 pady=15,                
                 justify=tk.CENTER,    
                 relief=tk.RAISED,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )

label.pack(pady=20)



def new_additional_habit_page():
    window = Toplevel(root)
    window.title("NEW HABIT PAGE")
    window.configure(background="sky blue")
    window.geometry("1200x700+50+50")
    window.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(window, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    habit_widgets = []
    saved_texts = []
    saved_habits_frame = tk.Frame(window, bg="sky blue")
    saved_habits_frame.place(x=850, y=300)
    display_label = tk.Label(window, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_habit():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = window.winfo_width() or 1200
        max_height = window.winfo_height() or 700
        num_widgets = len(habit_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(window, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        habit_check_var = tk.BooleanVar()
        habit_checkbox = tk.Checkbutton(window, text="", variable=habit_check_var,
                                        onvalue=True, offvalue=False,
                                        font=("Courier", 20, "bold"),
                                        bg="sky blue", fg="navy",
                                        selectcolor="light gray", activebackground="sky blue")
        habit_checkbox.place(x=x_pos, y=y_pos)
        make_draggable(habit_checkbox)

        text_box = tk.Text(window, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(window, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(window, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():
            habit_checkbox.destroy()
            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            habit_widgets.remove((habit_checkbox, text_box, delete_button, save_button))

        def save_text_and_add_button():
            title = title_entry.get().strip()
            content = text_box.get("1.0", tk.END).strip()
        
            if title and content:
                saved_habits.append({"title": title, "content": content})
                index = len(saved_habits) - 1
        
                btn = tk.Button(saved_habits_frame, text=title,
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)
        
            if title and content:
                saved_habits.append({"title": title, "content": content})
                index = len(saved_habits) - 1
        
                btn = tk.Button(saved_habits_frame, text=title,
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)
        
                # Optional: Clear after saving
                # title_entry.delete(0, tk.END)
                # text_box.delete("1.0", tk.END)


        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        habit_widgets.append((habit_checkbox, text_box, delete_button, save_button))

    add_button = tk.Button(window, text="+", command=new_habit, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(window, text="NEW PAGE", command=new_additional_habit_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_habit()


def open_new_window_habits_final_page():
    habit_page = Toplevel(root)
    habit_page.title("HABIT")
    habit_page.configure(background="sky blue")
    habit_page.geometry("1200x700+50+50")
    habit_page.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(habit_page, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    habit_widgets = []
    saved_texts = []
    saved_habits_frame = tk.Frame(habit_page, bg="sky blue")
    saved_habits_frame.place(x=850, y=300)
    display_label = tk.Label(habit_page, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_habit():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = habit_page.winfo_width() or 1200
        max_height = habit_page.winfo_height() or 700
        num_widgets = len(habit_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(habit_page, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        habit_check_var = tk.BooleanVar()
        habit_checkbox = tk.Checkbutton(habit_page, text="", variable=habit_check_var,
                                        onvalue=True, offvalue=False,
                                        font=("Courier", 20, "bold"),
                                        bg="sky blue", fg="navy",
                                        selectcolor="light gray", activebackground="sky blue")
        habit_checkbox.place(x=x_pos, y=y_pos)
        make_draggable(habit_checkbox)

        text_box = tk.Text(habit_page, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(habit_page, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(habit_page, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():
            habit_checkbox.destroy()
            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            habit_widgets.remove((habit_checkbox, text_box, delete_button, save_button))

        def save_text_and_add_button():
            habit_text = text_box.get("1.0", tk.END).strip()
            if habit_text:
                saved_texts.append(habit_text)
                index = len(saved_texts) - 1
                btn = tk.Button(saved_habits_frame, text=f"Habit {index + 1}",
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)

        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        habit_widgets.append((habit_checkbox, text_box, delete_button, save_button))

    add_button = tk.Button(habit_page, text="+", command=new_habit, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(habit_page, text="NEW PAGE", command=new_additional_habit_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_habit()

    
    
def open_new_window_habits_question():
    habit_page1 = Toplevel(root)  
    habit_page1.title("HABIT QUESTION")
    habit_page1.configure(background="sky blue")
    habit_page1.geometry("600x300+50+50")
    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(habit_page1, 
                 textvariable=text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 60, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=15,               
                 pady=15,                
                 justify=tk.CENTER,    
                 relief=tk.RAISED,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    label.pack(pady=20)
    habit_text_var = tk.StringVar()
    habit_text_var.set("Do you want to make a new habit?")
    habit_question = tk.Label(habit_page1, 
                 textvariable=habit_text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 40, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=5,               
                 pady=5,                
                 justify=tk.CENTER,    
                 relief=tk.FLAT,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    habit_question.pack(pady=80)
    tk.Button(habit_page1,
           text="Yes",
           command=open_new_window_habits_final_page,
           font = ("Courier", 24, "bold"),   
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2',
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3
    ).place(x=500, y=700)#Yes on page 2
    tk.Button(habit_page1,
           text="No",
           command=root.destroy,
           font = ("Courier", 24, "bold"),   
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2',
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3).place(x=900, y=700)



def new_additional_journal_page():
    window = Toplevel(root)
    window.title("NEW JOURNAL ENTRY PAGE")
    window.configure(background="sky blue")
    window.geometry("1200x700+50+50")
    window.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(window, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    journal_widgets = []
    saved_texts = []
    saved_journal_frame = tk.Frame(window, bg="sky blue")
    saved_journal_frame.place(x=850, y=300)
    display_label = tk.Label(window, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_journal():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = window.winfo_width() or 1200
        max_height = window.winfo_height() or 700
        num_widgets = len(journal_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(window, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        journal_check_var = tk.BooleanVar()
    

        text_box = tk.Text(window, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(window, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(window, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():

            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            journal_widgets.remove(( text_box, delete_button, save_button))

        def save_text_and_add_button():
            journal_text = text_box.get("1.0", tk.END).strip()
            if journal_text:
                saved_texts.append(journal_text)
                index = len(saved_texts) - 1
                btn = tk.Button(saved_journal_frame, text=f"JOURNAL ENTRY {index + 1}",
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)

        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        journal_widgets.append((text_box, delete_button, save_button))

    add_button = tk.Button(window, text="+", command=new_journal, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(window, text="NEW PAGE", command=new_additional_journal_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_journal()


def open_new_window_journal_final_page():
    journal_page = Toplevel(root)
    journal_page.title("JOURNAL ENTRY")
    journal_page.configure(background="sky blue")
    journal_page.geometry("1200x700+50+50")
    journal_page.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(journal_page, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    journal_widgets = []
    saved_texts = []
    saved_journal_frame = tk.Frame(journal_page, bg="sky blue")
    saved_journal_frame.place(x=850, y=300)
    display_label = tk.Label(journal_page, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_journal():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = journal_page.winfo_width() or 1200
        max_height = journal_page.winfo_height() or 700
        num_widgets = len(journal_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(journal_page, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        journal_check_var = tk.BooleanVar()
        

        text_box = tk.Text(journal_page, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(journal_page, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(journal_page, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():

            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            journal_widgets.remove((text_box, delete_button, save_button))

        def save_text_and_add_button():
            journal_text = text_box.get("1.0", tk.END).strip()
            if journal_text:
                saved_texts.append(journal_text)
                index = len(saved_texts) - 1
                btn = tk.Button(saved_journal_frame, text=f"Journal entry {index + 1}",
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)

        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        journal_widgets.append(( text_box, delete_button, save_button))

    add_button = tk.Button(journal_page, text="+", command=new_journal, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(journal_page, text="NEW PAGE", command=new_additional_journal_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_journal()

  
def open_new_window_journal_question():
    journal_page1 = Toplevel(root)  
    journal_page1.title("JOURNAL QUESTION")
    journal_page1.configure(background="sky blue")
    journal_page1.geometry("600x300+50+50")
    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(journal_page1, 
                 textvariable=text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 60, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=15,               
                 pady=15,                
                 justify=tk.CENTER,    
                 relief=tk.RAISED,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    label.pack(pady=20)
    journal_text_var = tk.StringVar()
    journal_text_var.set("Do you want to make a new journal entry?")
    journal_question = tk.Label(journal_page1, 
                 textvariable=journal_text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 40, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=5,               
                 pady=5,                
                 justify=tk.CENTER,    
                 relief=tk.FLAT,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    journal_question.pack(pady=80)
    tk.Button(journal_page1,
           text="Yes",
           command=open_new_window_journal_final_page,
           font = ("Courier", 24, "bold"),   
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2',  
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3).place(x=500, y=700)
    tk.Button(journal_page1,
           text="No",
           command=root.destroy,
           font = ("Courier", 24, "bold"), 
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2',
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3).place(x=900, y=700)

def new_additional_todos_page():
    window = Toplevel(root)
    window.title("NEW TO-DO PAGE")
    window.configure(background="sky blue")
    window.geometry("1200x700+50+50")
    window.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(window, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    todos_widgets = []
    saved_texts = []
    saved_todos_frame = tk.Frame(window, bg="sky blue")
    saved_todos_frame.place(x=850, y=300)
    display_label = tk.Label(window, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_todos():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = window.winfo_width() or 1200
        max_height = window.winfo_height() or 700
        num_widgets = len(todos_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(window, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        todos_check_var = tk.BooleanVar()
        todos_checkbox = tk.Checkbutton(window, text="", variable=todos_check_var,
                                        onvalue=True, offvalue=False,
                                        font=("Courier", 20, "bold"),
                                        bg="sky blue", fg="navy",
                                        selectcolor="light gray", activebackground="sky blue")
        todos_checkbox.place(x=x_pos, y=y_pos)
        make_draggable(todos_checkbox)

        text_box = tk.Text(window, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(window, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(window, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():
            todos_checkbox.destroy()
            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            todos_widgets.remove((todos_checkbox, text_box, delete_button, save_button))

        def save_text_and_add_button():
            todos_text = text_box.get("1.0", tk.END).strip()
            if todos_text:
                saved_texts.append(todos_text)
                index = len(saved_texts) - 1
                btn = tk.Button(saved_todos_frame, text=f"To-Do {index + 1}",
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)

        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        todos_widgets.append((todos_checkbox, text_box, delete_button, save_button))

    add_button = tk.Button(window, text="+", command=new_todos, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(window, text="NEW PAGE", command=new_additional_todos_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_todos()


def open_new_window_todos_final_page():
    todos_page = Toplevel(root)
    todos_page.title("To-Do")
    todos_page.configure(background="sky blue")
    todos_page.geometry("1200x700+50+50")
    todos_page.update_idletasks()

    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(todos_page, textvariable=text_var, anchor=tk.CENTER, bg="sky blue",
                     height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                     cursor="hand2", fg="Lavender", padx=15, pady=15,
                     justify=tk.CENTER, relief=tk.RAISED, underline=0,
                     wraplength=0, highlightbackground="snow", highlightthickness=3)
    label.pack(pady=20)

    todos_widgets = []
    saved_texts = []
    saved_todos_frame = tk.Frame(todos_page, bg="sky blue")
    saved_todos_frame.place(x=850, y=300)
    display_label = tk.Label(todos_page, text="", wraplength=300, bg="lavender", fg="black",
                             justify="left", anchor="nw", width=30, height=6)
    display_label.place(x=850, y=500)

    def show_saved_text(index):
        display_label.config(text=saved_texts[index])

    def make_draggable(widget):
        def on_start(event):
            widget.startX = event.x
            widget.startY = event.y
        def on_drag(event):
            x = widget.winfo_x() - widget.startX + event.x
            y = widget.winfo_y() - widget.startY + event.y
            widget.place(x=x, y=y)
        widget.bind("<ButtonPress-1>", on_start)
        widget.bind("<B1-Motion>", on_drag)

    def new_todos():
        widget_height = 70
        widget_width = 600
        padding_top = 300
        padding_left = 50
        max_width = todos_page.winfo_width() or 1200
        max_height = todos_page.winfo_height() or 700
        num_widgets = len(todos_widgets)
        widgets_per_column = (max_height - padding_top) // widget_height
        col = num_widgets // widgets_per_column
        row = num_widgets % widgets_per_column
        x_pos = padding_left + col * widget_width
        y_pos = padding_top + row * widget_height

        if x_pos + widget_width > max_width:
            error_var = tk.StringVar()
            error_var.set("No more space❌")
            full_label = tk.Label(todos_page, textvariable=error_var, anchor=tk.CENTER, bg="sky blue",
                                  height=3, width=60, bd=3, font=("Courier", 60, "bold"),
                                  cursor="hand2", fg="Lavender", padx=15, pady=15,
                                  justify=tk.CENTER, relief=tk.RAISED, underline=0,
                                  wraplength=0, highlightbackground="snow", highlightthickness=3)
            full_label.pack(pady=20)
            full_label.after(2000, full_label.pack_forget)
            return

        todos_check_var = tk.BooleanVar()
        todos_checkbox = tk.Checkbutton(todos_page, text="", variable=todos_check_var,
                                        onvalue=True, offvalue=False,
                                        font=("Courier", 20, "bold"),
                                        bg="sky blue", fg="navy",
                                        selectcolor="light gray", activebackground="sky blue")
        todos_checkbox.place(x=x_pos, y=y_pos)
        make_draggable(todos_checkbox)

        text_box = tk.Text(todos_page, height=3, width=30, bg="Lavender", fg="grey1")
        text_box.place(x=x_pos + 100, y=y_pos)
        text_box.insert(tk.END, "Type something here...")
        make_draggable(text_box)

        delete_button = tk.Button(todos_page, text="🗑️", font=("Courier", 14))
        delete_button.place(x=x_pos + 460, y=y_pos)
        make_draggable(delete_button)

        save_button = tk.Button(todos_page, text="💾", font=("Courier", 14))
        save_button.place(x=x_pos + 500, y=y_pos)
        make_draggable(save_button)

        def delete_widgets():
            todos_checkbox.destroy()
            text_box.destroy()
            delete_button.destroy()
            save_button.destroy()
            todos_widgets.remove((todos_checkbox, text_box, delete_button, save_button))

        def save_text_and_add_button():
            todos_text = text_box.get("1.0", tk.END).strip()
            if todos_text:
                saved_texts.append(todos_text)
                index = len(saved_texts) - 1
                btn = tk.Button(saved_todos_frame, text=f"To-do {index + 1}",
                                command=lambda i=index: show_saved_text(i),
                                font=("Courier", 10, "bold"),
                                bg="lavender", wraplength=140)
                btn.pack(pady=2)

        delete_button.config(command=delete_widgets)
        save_button.config(command=save_text_and_add_button)

        todos_widgets.append((todos_checkbox, text_box, delete_button, save_button))

    add_button = tk.Button(todos_page, text="+", command=new_todos, font=("Courier", 24, "bold"),
                           fg='grey1', bg='SlateBlue2', activebackground='SlateBlue2',
                           highlightbackground='SlateBlue2', highlightcolor='SlateBlue2',
                           highlightthickness=2, width=5, height=1)
    add_button.place(x=1200, y=350)

    add_new_button = tk.Button(todos_page, text="NEW PAGE", command=new_additional_todos_page,
                           font=("Courier", 24, "bold"), fg='grey1', bg='SlateBlue2',
                           activebackground='SlateBlue2', highlightbackground='SlateBlue2',
                           highlightcolor='SlateBlue2', highlightthickness=2, width=12, height=1)
    add_new_button.place(x=1200, y=550)

    new_todos()

    
 
def open_new_window_todos_question():
    todos_page1 = Toplevel(root)  
    todos_page1.title("TO-DO QUESTION")
    todos_page1.configure(background="sky blue")
    todos_page1.geometry("600x300+50+50")
    text_var.set("L  i  f  e  H  u  b")
    label = tk.Label(todos_page1, 
                 textvariable=text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 60, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=15,               
                 pady=15,                
                 justify=tk.CENTER,    
                 relief=tk.RAISED,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    label.pack(pady=20)
    todos_text_var = tk.StringVar()
    todos_text_var.set("Do you want to make a new to-do?")
    todos_question = tk.Label(todos_page1, 
                 textvariable=todos_text_var, 
                 anchor=tk.CENTER,       
                 bg="sky blue",      
                 height=3,              
                 width=60,              
                 bd=3,                  
                 font=("Courier", 40, "bold"), 
                 cursor="hand2",   
                 fg="Lavender",             
                 padx=5,               
                 pady=5,                
                 justify=tk.CENTER,    
                 relief=tk.FLAT,     
                 underline=0,           
                 wraplength=0,
                 highlightbackground="snow",  
                 highlightthickness=3
                )
    todos_question.pack(pady=80)
    tk.Button(todos_page1,
           text="Yes",
           command=open_new_window_todos_final_page,
           font = ("Courier", 24, "bold"),
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2',
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3).place(x=500, y=700)
    tk.Button(todos_page1,
           text="No",
           command=root.destroy,
           font = ("Courier", 24, "bold"),
           fg='grey1',
           activebackground='SlateBlue2',
           highlightbackground='SlateBlue2', 
           highlightcolor='SlateBlue2',
           highlightthickness=2,
           width = 15,
           height = 3).place(x=900, y=700)


tk.Button(root,
    text="HABIT",
    command=open_new_window_habits_question,
    font = ("Courier", 24, "bold"),
    bg='SlateBlue2',
    fg='grey1',
    activebackground='SlateBlue2',
    highlightbackground='SlateBlue2', 
    highlightcolor='SlateBlue2',
    highlightthickness=2,
    width = 15,
    height = 3
).place(x=150, y=300)
tk.Button(root,
          text="JOURNAL ENTRY",
          command=open_new_window_journal_question,bg='SlateBlue2',
          font = ("Courier", 24, "bold"),
          fg='grey1',
          activebackground='SlateBlue2',
          highlightbackground='SlateBlue2', 
          highlightcolor='SlateBlue2',
          highlightthickness=2,
          width = 15,
          height = 3
).place(x=600, y=300)
tk.Button(root,
          text="TO-DO",
          command=open_new_window_todos_question,
          font = ("Courier", 24, "bold"),
          fg='grey1',
          activebackground='SlateBlue2',
          highlightbackground='SlateBlue2', 
          highlightcolor='SlateBlue2',
          highlightthickness=2,
          width = 15,
          height = 3
).place(x=1050, y=300)





    

root.mainloop()
